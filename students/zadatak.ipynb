# %%
import sys

# !pip install -q google-generativeai

import google.generativeai as genai
from google.colab import userdata

try:
    GOOGLE_API_KEY = userdata.get('GOOGLE_API_KEY')
    genai.configure(api_key=GOOGLE_API_KEY)
    print("Google Generative AI library installed and API key configured.")
except Exception as e:
    print(f"Error configuring Google API key: {e}")
    print("Please ensure 'GOOGLE_API_KEY' is set in Colab Secrets.")
# Out:
# Google Generative AI library installed and API key configured.

# %%
import google.generativeai as genai

def student_model(prompt: str) -> str:
    print(f"Student model received prompt: {prompt}")
    student_llm = genai.GenerativeModel('gemini-2.5-flash')

    # Generate content using the student model
    try:
        response = student_llm.generate_content(prompt)
        if response.text:
            solution = response.text
        else:
            solution = "No solution generated by student model."
    except Exception as e:
        solution = f"Error generating solution: {e}"
        print(solution)

    print(f"Student's solution: {solution}")
    return solution

print("Student model (Gemini Flash) redefined.")
# Out:
# Student model (Gemini Flash) redefined.

# %%
import google.generativeai as genai

def professor_model(student_solution: str, current_prompt: str) -> str:
    print(f"Professor model received solution: {student_solution}\nfor prompt: {current_prompt}")

    # Initialize the stronger Gemini model for the professor
    professor_llm = genai.GenerativeModel('gemini-2.5-pro') # Using a 'stronger' model for the professor

    professor_prompt_text = f"""You are an expert prompt refiner. Your goal is to analyze a student's solution to a given prompt and provide a refined prompt that would lead to a better, more detailed, or more accurate solution in the next iteration.

Here is the current prompt:
`{current_prompt}`

Here is the student's solution based on that prompt:
`{student_solution}`

Based on the student's solution, identify areas where the original prompt could be improved. Think about what information was missing, ambiguous, or what constraints were not clear enough for the student to provide an optimal solution. Your refined prompt should guide the student towards a better answer by:
- Adding clarity or specificity.
- Introducing new constraints or considerations.
- Suggesting a different approach or focus.
- Asking for more detail or specific examples.

Your output MUST be ONLY the refined prompt string. Do not include any conversational text, prefixes like 'Refined Prompt:', or any other formatting. Just the new prompt string.
"""

    # Generate the refined prompt using the professor model
    try:
        response = professor_llm.generate_content(professor_prompt_text)
        if response.text:
            next_refined_prompt = response.text.strip()
        else:
            next_refined_prompt = current_prompt # Fallback if no text is generated
            print("Professor model did not return a refined prompt, using current prompt as fallback.")
    except Exception as e:
        next_refined_prompt = current_prompt # Fallback on error
        print(f"Error generating refined prompt with Professor model: {e}. Using current prompt as fallback.")

    print(f"\nProfessor's Feedback (Verbose):\n")
    print(f"Original Prompt: {current_prompt}")
    print(f"Student's Solution: {student_solution}")
    print(f"Refined Prompt for next iteration: {next_refined_prompt}")

    return next_refined_prompt

print("Professor model (Gemini Pro) redefined for intelligent prompt refinement.")
# Out:
# Professor model (Gemini Pro) redefined for intelligent prompt refinement.

# %%
prompt_history = []
student_solution_history = []

initial_prompt = "A city wants to implement an autonomous drone delivery system. Each drone has a limited battery capacity, a maximum payload weight, and a maximum flight distance. Customers can place orders for packages of varying weights at different locations throughout the city. Some areas have no-fly zones, and weather conditions can affect flight time. Task: Design an algorithm that schedules and routes drones to deliver all packages in the shortest total time possible, while respecting battery limits, payload capacities, no-fly zones, and weather constraints."

prompt_history.append(initial_prompt)
print(f"Initial Prompt appended to history: {initial_prompt}")

# First student solution
student_initial_solution = student_model(initial_prompt)
student_solution_history.append(student_initial_solution)
print(f"\nInitial Student Solution: {student_initial_solution}")

# First iteration: Professor evaluates initial student solution
# The professor_model now directly returns the refined prompt
refined_prompt_1 = professor_model(student_initial_solution, initial_prompt)

prompt_history.append(refined_prompt_1)

print(f"\nProfessor's Feedback (Returned Refined Prompt - Iteration 1):\n{refined_prompt_1}")

num_additional_iterations = 4  # As specified in the previous notebook cell
current_prompt = refined_prompt_1

for i in range(num_additional_iterations):
    iteration_number = i + 2  # Start iteration numbering from 2
    print(f"\n--- Iteration {iteration_number} ---")

    # Student generates a solution based on the current prompt
    student_solution = student_model(current_prompt)
    student_solution_history.append(student_solution)
    print(f"\nStudent's Solution (Iteration {iteration_number}):\n{student_solution}")

    # Professor evaluates the solution and returns a refined prompt
    next_refined_prompt = professor_model(student_solution, current_prompt)
    prompt_history.append(next_refined_prompt)
    print(f"\nProfessor's Feedback (Returned Refined Prompt - Iteration {iteration_number}):\n{next_refined_prompt}")

    # Update current_prompt for the next iteration
    current_prompt = next_refined_prompt

print("\nIterative prompt refinement loop completed.")
# Out:
# Izlaz streaminga skraćen je na ovoliko posljednjih redaka: 5000.
#                 best_assignment = (drone.id, proposed_route_new_mission, proposed_schedule_new_mission)
#
#     # 2. Commit or Queue
#     IF best_overall_score > CONFIG.ASSIGNMENT_THRESHOLD: # Threshold ensures we don't pick a very bad option
#         drone_id, route, schedule = best_assignment
#         FSM.assign_package_to_drone(drone_id, new_package_order.id, route, schedule)
#         RP.update_drone_mission(drone_id, route, schedule) # Finalize detailed route
#         OMS.update_package_status(new_package_order.id, "assigned")
#         RETURN TRUE
#     ELSE:
#         OMS.add_package_to_pending_queue(new_package_order.id)
#         RETURN FALSE
#
# # Helper function for calculating scores
# FUNCTION EvaluateObjectiveFunction(drone, proposed_route, proposed_schedule, focused_package):
#     # Retrieve all packages now on this drone's mission (original + focused_package)
#     all_packages_on_mission = GetPackagesFromSchedule(proposed_schedule)
#
#     # Calculate Customer Satisfaction (W_cust_sat)
#     avg_delivery_time = CalculateAverageDeliveryTime(proposed_schedule)
#     max_delivery_time = CalculateMaximumDeliveryTime(proposed_schedule)
#     express_penalty = CalculateExpressPenalty(proposed_schedule, all_packages_on_mission)
#     time_window_penalty = CalculateTimeWindowPenalty(proposed_schedule, all_packages_on_mission)
#
#     cust_sat_score = (
#         W_CS_AVG * (-avg_delivery_time) +
#         W_CS_MAX * (-max_delivery_time) +
#         W_CS_EXP * (-express_penalty) +
#         W_CS_TW * (-time_window_penalty)
#     )
#
#     # Calculate Operational Efficiency (W_op_eff)
#     num_deliveries = len(all_packages_on_mission)
#     mission_duration = proposed_schedule.total_duration
#     drone_payload_util = CalculatePayloadUtilization(drone, all_packages_on_mission)
#
#     op_eff_score = (
#         W_OE_DEL_RATE * (num_deliveries / mission_duration) +
#         W_OE_PAYLOAD * drone_payload_util
#     )
#
#     # Calculate Energy Cost (W_energy)
#     total_energy_consumption = RP.EstimateEnergyConsumption(drone, proposed_route)
#     num_battery_stops = proposed_schedule.num_charging_or_swap_stops
#
#     energy_cost_score = (
#         W_EC_CONS * (-total_energy_consumption) +
#         W_EC_STOPS * (-num_battery_stops) # Penalize frequent stops
#     )
#
#     RETURN cust_sat_score + op_eff_score + energy_cost_score
# ```
#
# ---
#
# ### 3. Dynamic Route Planning
#
# The `RoutePlanner` is responsible for generating and updating detailed, executable flight paths. It performs continuous optimization based on real-time data.
#
# **Initial Route Calculation (VRP-like):**
# When the DS assigns a mission to a drone, the RP solves a variant of the Vehicle Routing Problem with Time Windows (VRPTW) and heterogeneous fleet constraints.
# 1.  **Stop Sequencing:** For a drone with multiple pickups/deliveries, the RP determines the optimal sequence of stops. This is a TSP-like problem solved using heuristics (e.g., insertion heuristics, savings algorithms, or metaheuristics like genetic algorithms, simulated annealing) to find the shortest/most efficient path.
# 2.  **Pathfinding:** Between each stop, an A* search algorithm (or similar shortest path algorithm) is used on the city graph, considering:
#     *   **No-Fly Zones:** Permanent and dynamic zones are strictly avoided. If a zone appears on an existing path, re-routing occurs immediately.
#     *   **Wind Conditions:** EDS provides regional wind data. The drone's ground speed and battery consumption are calculated based on its airspeed relative to the wind (e.g., `ground_speed = drone_airspeed + wind_speed_component_along_path`). Battery consumption is non-linearly affected (e.g., proportional to `(drone_airspeed - wind_component)^3` or similar aero-dynamic model).
#     *   **Payload:** Heavier payload increases battery consumption.
#     *   **Drone Model:** Light-duty (faster, less battery) vs. Heavy-duty (slower, more battery, higher payload).
# 3.  **Battery Management Integration:** The RP inherently plans for battery needs:
#     *   Estimates consumption for the entire route.
#     *   If current battery is insufficient, it identifies the optimal point in the route to divert to a depot for an instantaneous swap or a charging station for a recharge. This decision is based on comparing:
#         *   **(Time to Depot + Swap Time + Time to Next Task)** vs. **(Time to Charging Station + Recharge Time + Time to Next Task)**.
#         *   Recharge time is calculated based on current battery level, target charge level, and charging station power.
#         *   Depots are preferred due to speed, but charging stations provide more flexibility.
#     *   The chosen battery stop is inserted into the sequence of stops.
#
# **Dynamic Updates and Decision Logic:**
#
# Routes are constantly monitored and can be dynamically re-calculated or adjusted based on new events:
#
# 1.  **New Package Assignment to In-Flight Drone (Detouring):**
#     *   If the DS assigns a new high-priority package to a drone already on a mission, the RP recalculates the drone's entire remaining route.
#     *   It tries to insert the new pickup/delivery into the current sequence of stops, minimizing delays to existing packages while ensuring the new package's constraints (priority, time window) are met. This is a complex insertion heuristic.
#     *   If no feasible insertion exists, the package might be re-queued or assigned to another drone.
#
# 2.  **Drone State Changes:**
#     *   **Battery Low:** If a drone's battery drops unexpectedly (e.g., due to stronger headwind than forecasted), the RP immediately re-evaluates the drone's ability to reach its next destination *and* a charging facility. It might trigger an immediate diversion to the nearest safe landing spot, depot, or charging station, overriding existing tasks.
#     *   **Package Delivered/Picked Up:** Upon confirmation, the drone's task list is updated, potentially triggering the next leg of its mission.
#
# 3.  **Environmental Changes:**
#     *   **Dynamic No-Fly Zone:** If a new no-fly zone appears along a drone's current or planned path, the RP immediately recalculates an alternative path avoiding the zone. If no viable path exists (e.g., drone is trapped or cannot avoid), it initiates an emergency landing procedure to the nearest safe location.
#     *   **Weather Deterioration:** If wind speeds increase significantly or other adverse conditions emerge, the RP recalculates estimated flight times and battery consumption. This might trigger early battery management actions or even a temporary grounding if conditions become unsafe, leading to re-assignment of packages.
#
# 4.  **Emergency Situations (Robustness):**
#     *   **Drone Malfunction:** Upon receiving a malfunction alert from FSM, the RP's priority is to guide the drone to the nearest safe landing zone or depot, bypassing all other tasks. All packages on board are immediately marked for re-assignment by the DS.
#
# ---
#
# ### 4. Scalability and Robustness
#
# **Scalability:**
#
# *   **Computational Complexity:**
#     *   **Assignment Heuristic:** The core bottleneck is the `RP.CalculateRoute` function, which is a VRP-like problem. For `N_drones` and `K` packages (stops), an exact solution is NP-hard. Our approach uses heuristics. If `CalculateRoute` takes `O(K^2)` or `O(K^3)` with good heuristics (e.g., greedy insertion, local search), then the `AssignPackage` function would be `O(N_drones * K^x)`.
#     *   **Route Planning:** The A* pathfinding between stops is typically `O(E + V log V)` where E is edges, V is vertices in the city graph.
# *   **Strategies for Scaling:**
#     1.  **Hierarchical Zoning:** The city is divided into operational zones. Drones are primarily assigned to zones. New orders first seek drones within their zone, then adjacent, then globally. This limits the `N_drones` and `K` considered in `CalculateRoute` for most common scenarios.
#     2.  **Pre-computation & Caching:**
#         *   Pre-calculate shortest paths and battery costs between critical nodes (depots, major hubs, common vendor/customer clusters) for different drone types and average weather.
#         *   Cache results of `RP.CalculateRoute` for similar drone states and package combinations.
#     3.  **Approximate Algorithms & Heuristics:** Rely heavily on efficient approximation algorithms for the VRP-like problems within the RP. Machine learning models can be trained offline to quickly predict good routes or assignments.
#     4.  **Parallel Processing:** The evaluation of `candidate_drones` in the `AssignPackage` function can be parallelized. Each drone's potential route can be assessed concurrently.
#     5.  **Rolling Horizon Optimization:** Instead of optimizing for the entire day, the DS might re-optimize the schedule for the next 1-2 hours or for the next `X` packages, then re-evaluate. This reduces the problem size.
#     6.  **Event-Driven Architecture:** Calculations are only triggered by significant events (new order, drone status change, environmental update), not on a fixed, frequent cycle for the entire fleet.
#     7.  **Priority-Based Resource Allocation:** Critical packages (Express, time-window) or drones in critical states (low battery, malfunction) receive higher computational priority for route planning.
#
# **Robustness:**
#
# The system is designed to handle unexpected events gracefully:
#
# 1.  **Drone Malfunctions:**
#     *   **Detection:** FSM immediately detects anomaly through telemetry (e.g., unusual attitude, power drop).
#     *   **Action:** RP receives notification and immediately calculates a new, shortest, safest path to the nearest safe landing zone or depot. All packages on board are removed from the drone's manifest and put back into the OMS's `PendingOrdersQueue` with elevated priority.
#     *   **Re-assignment:** DS is triggered to re-assign these critical packages to other available drones.
#
# 2.  **Sudden Weather Deterioration:**
#     *   **Detection:** EDS provides real-time updates. If conditions (e.g., extreme wind, heavy rain) exceed drone operational limits or significantly impact battery life.
#     *   **Action:** RP re-calculates all affected drone routes. Drones might be re-routed to avoid severe zones, land early at safe spots, or divert to a depot. In extreme cases, a general "grounding" order might be issued, and all in-flight packages are marked for re-assignment when conditions improve.
#
# 3.  **Dynamic No-Fly Zone Appearance:**
#     *   **Detection:** IM receives immediate updates from external authorities.
#     *   **Action:** RP is immediately triggered for all drones whose paths intersect the new zone. New routes are calculated avoiding the zone. If a drone is already inside, it calculates the fastest, safest exit path. Packages may experience delays, and critical packages might trigger re-assignment if delays are too long.
#
# 4.  **Package Cancellation/Priority Change:**
#     *   **Action:** OMS updates the package status. If cancelled, the drone's route is immediately re-optimized to remove the stop. If priority changes, the package might be re-evaluated for assignment or for insertion into another drone's route.
#
# 5.  **Depot/Charging Station Unavailability:**
#     *   **Detection:** IM monitors status.
#     *   **Action:** RP will only consider available facilities. If a drone was en route to a now-unavailable facility, it will be re-routed to the next best option.
#
# 6.  **Redundancy and Failover:** Maintain a pool of pre-charged, idle drones at various depots to quickly replace malfunctioning drones or handle surge demand. The central control system can be architected with failover mechanisms to ensure continuous operation.
#
# ---
#
# ### 5. Evaluation Strategy
#
# A robust simulation framework is essential to validate the algorithm's performance, especially given the multi-objective optimization and dynamic environment.
#
# **Simulation Framework:**
#
# 1.  **City Model:**
#     *   **Geographical Graph:** Represent the city as a weighted directed graph where nodes are intersections, potential pick-up/drop-off points, depots, and charging stations. Edges represent flight paths with associated distances, base travel times, and altitude profiles.
#     *   **No-Fly Zones:** Define static and dynamic no-fly zone polygons.
#     *   **Depots & Charging Stations:** Locations, capacities (for charging stations), battery swap times (instantaneous for depots).
# 2.  **Drone Models:**
#     *   **Parameters:** For Light-Duty and Heavy-Duty drones: Max payload, battery capacity, base cruise speed, battery consumption rate (idle, flying, varying with payload and airspeed relative to wind), charging rate.
#     *   **Failure Model:** Introduce a probability of random drone malfunctions (e.g., engine failure, navigation error) at varying rates.
# 3.  **Package Generator:**
#     *   **Arrival Rate:** Configurable arrival rate for new orders (e.g., Poisson process, or historical data-driven). Can simulate peak hours vs. off-peak.
#     *   **Package Attributes:** Randomly generate:
#         *   Vendor/Customer Locations (spatial distribution mimicking urban density).
#         *   Weight (within drone limits).
#         *   Priority (Standard/Express ratio).
#         *   Time Window Constraints (percentage of orders).
#         *   Delivery Deadlines (for Express, general target).
# 4.  **Environmental Model:**
#     *   **Weather Service:** Simulate a forecasting service providing regional wind speed/direction, precipitation, temperature, updated periodically. Wind model should vary spatially and temporally.
#     *   **Dynamic No-Fly Zones:** Events for sudden appearance/disappearance of temporary no-fly zones.
# 5.  **Event-Driven Simulator:**
#     *   Advance time in discrete steps or based on events.
#     *   Process events: package arrival, drone departure/arrival at waypoint/stop, battery level update, weather update, drone malfunction, no-fly zone change.
#     *   Record all drone movements, battery consumption, package statuses, and decisions made by the DS/RP.
#
# **Metrics to Track (aligned with KPIs):**
#
# 1.  **Customer Satisfaction:**
#     *   **Average Delivery Time (ADT):** Mean time from order placement to delivery completion.
#     *   **Maximum Delivery Time (MDT):** Longest delivery time observed.
#     *   **Express On-Time Rate:** Percentage of Express packages delivered within their target time.
#     *   **Time Window Compliance:** Percentage of packages delivered within their specified time windows.
#     *   **Penalty Score:** Sum of all incurred penalties for missed targets/windows.
#
# 2.  **Operational Efficiency:**
#     *   **Throughput:** Total packages delivered per simulation hour/day.
#     *   **Deliveries per Drone Hour:** Average number of deliveries made by an individual drone per hour of its operational time.
#     *   **Drone Utilization Rate:** Percentage of time drones are actively flying with a payload (excluding idle time, charging, maintenance).
#     *   **Payload Utilization:** Average percentage of maximum payload capacity utilized per flight segment.
#     *   **Multi-Package Delivery Rate:** Percentage of deliveries that are part of a multi-stop route.
#     *   **Idle Time:** Average time drones spend waiting for tasks.
#
# 3.  **Energy Cost:**
#     *   **Total Energy Consumption (kWh):** Sum of all battery energy consumed across the fleet.
#     *   **Energy per Delivery (kWh/delivery):** Total energy divided by total deliveries.
#     *   **Battery Cycle Count:** Number of full charge/discharge cycles experienced by batteries (related to battery lifespan).
#     *   **Charging/Swap Time:** Total time spent by fleet either charging or undergoing battery swaps.
#
# **Baseline Strategies for Comparison:**
#
# 1.  **Nearest Available Drone (NAD):** A simple greedy approach where a new package is assigned to the closest drone that can physically carry it and has enough battery to complete the mission. No multi-stop optimization.
# 2.  **First Available Drone (FAD):** Assign to the first drone that becomes idle and can take the package, regardless of proximity.
# 3.  **Homogeneous Fleet (e.g., All Light-Duty or All Heavy-Duty):** Run simulations using only one type of drone to quantify the benefits of fleet heterogeneity.
# 4.  **Greedy Multi-Stop (without advanced battery/weather):** A NAD approach that attempts to combine deliveries into multi-stop routes but lacks sophisticated battery planning or real-time weather integration.
#
# **Experimentation & Analysis:**
#
# *   **Varying Load:** Run simulations under low, medium, and high package arrival rates to test scalability.
# *   **Parameter Sensitivity:** Vary the weights (W_cust_sat, W_op_eff, W_energy) in the objective function to understand trade-offs and find optimal balance.
# *   **Environmental Stress Tests:** Simulate frequent and severe weather changes, high rates of dynamic no-fly zones, and drone malfunctions to assess robustness.
# *   **Fleet Composition:** Experiment with different ratios of Light-Duty vs. Heavy-Duty drones.
# *   **Statistical Significance:** Run multiple simulation trials for each scenario with different random seeds to ensure statistical significance of results.
#
# By systematically comparing the proposed algorithm against these baselines and across various operational conditions, its effectiveness, scalability, and robustness can be thoroughly evaluated.
#
# Student's Solution (Iteration 2):
# The deployment of a heterogeneous autonomous drone fleet for real-time delivery in a dynamic urban environment presents a complex optimization challenge. The goal is to balance customer satisfaction, operational efficiency, and energy cost, which often conflict. This design outlines a robust, scalable algorithm to address these challenges.
#
# ---
#
# ## Real-Time Heterogeneous Drone Scheduling and Routing System
#
# ### 1. System Architecture
#
# The system operates under a central control platform, integrating various modules for real-time data processing, decision-making, and drone command.
#
# **High-Level Components:**
#
# 1.  **Order Management System (OMS):**
#     *   **Function:** Receives new package orders from various vendors, validates them, and assigns unique IDs. Manages package priorities (Standard, Express), weights, delivery time windows, and current status.
#     *   **Input:** Real-time package requests.
#     *   **Output:** Prioritized package queue to the Dynamic Scheduler.
#
# 2.  **Fleet State Monitor (FSM):**
#     *   **Function:** Maintains a comprehensive, real-time database of all drones in the fleet. Tracks drone location (GPS), current status (idle, flying, charging, maintenance, malfunctioning), battery level, current payload, assigned tasks, and estimated time of arrival (ETA) at next waypoint/destination.
#     *   **Input:** Telemetry data from drones.
#     *   **Output:** Real-time drone status to Dynamic Scheduler and Route Planner.
#
# 3.  **Infrastructure Manager (IM):**
#     *   **Function:** Manages static and dynamic infrastructure data. Tracks locations and availability of depots (with battery swap capabilities) and public charging stations. Monitors capacity and queue times for charging stations. Manages permanent and dynamic no-fly zones.
#     *   **Input:** Static infrastructure data, real-time status from depots/charging stations, updates on dynamic no-fly zones (e.g., from air traffic control).
#     *   **Output:** Infrastructure availability and no-fly zone data to Dynamic Scheduler and Route Planner.
#
# 4.  **Environmental Data Service (EDS):**
#     *   **Function:** Integrates real-time and forecasted environmental data, primarily weather conditions (wind speed, direction, precipitation, temperature) across different city regions.
#     *   **Input:** APIs from weather forecasting services.
#     *   **Output:** Regional weather data to Route Planner for flight path calculation and battery consumption estimation.
#
# 5.  **Dynamic Scheduler (DS) - *The Brain*:**
#     *   **Function:** The core decision-making unit. Upon receiving a new order or a drone becoming available, it determines the optimal drone (or set of drones) to assign tasks to. It uses a sophisticated heuristic to evaluate potential assignments against the multi-objective KPIs.
#     *   **Input:** Package queue from OMS, drone states from FSM, infrastructure data from IM, environmental data from EDS.
#     *   **Output:** Drone assignments and high-level mission plans to the Route Planner.
#
# 6.  **Route Planner (RP):**
#     *   **Function:** Detailed pathfinding for individual drones. Given a drone and a sequence of tasks (pickups/deliveries/charging), it calculates the precise flight path (sequence of waypoints), considering no-fly zones, wind conditions, battery consumption, and drone specific parameters. It also estimates ETA for each leg and overall mission duration.
#     *   **Input:** Drone assignment and mission plan from DS, detailed drone specs, infrastructure data from IM, environmental data from EDS.
#     *   **Output:** Optimized flight plan (waypoints, speeds, estimated battery use, ETAs) to the Communication Module.
#
# 7.  **Communication Module:**
#     *   **Function:** Facilitates secure, real-time communication between the central system and individual drones. Sends flight plans and receives telemetry data.
#     *   **Input:** Flight plans from RP.
#     *   **Output:** Drone commands, receives drone telemetry.
#
# 8.  **Database/Knowledge Base:**
#     *   **Function:** Stores all static and dynamic data (drone specifications, depot locations, historical package data, past route performance, etc.) to support all modules.
#
# **Interaction Flow:**
#
# 1.  **New Order:** OMS receives an order and adds it to the package queue.
# 2.  **Assignment Request:** DS continuously monitors the package queue and available/soon-to-be-available drones.
# 3.  **Candidate Evaluation:** For each new order, DS queries FSM, IM, and EDS to identify suitable candidate drones and evaluates potential assignments using its core heuristic. This involves hypothetical route calculations by the RP.
# 4.  **Optimal Assignment:** DS selects the best assignment and commits it.
# 5.  **Detailed Route:** RP takes the assigned drone and its new/updated mission to generate a detailed flight path.
# 6.  **Drone Execution:** Communication Module sends the flight plan to the drone. The drone executes, sending back telemetry to FSM.
# 7.  **Dynamic Updates:** FSM, IM, EDS constantly feed updates, triggering re-evaluation and dynamic re-routing if necessary.
#
# ---
#
# ### 2. Core Assignment Heuristic
#
# The `DynamicScheduler` uses a heuristic to make assignment decisions for new package orders. The core challenge is balancing the three conflicting KPIs.
#
# **Objective Function:** A weighted sum combining the normalized scores of each KPI.
# `OverallScore = W_cust_sat * CustomerSatisfactionScore + W_op_eff * OperationalEfficiencyScore + W_energy * EnergyCostScore`
# Where `W` are configurable weighting factors.
#
# **`CustomerSatisfactionScore` Components:**
# *   `- (Estimated_Delivery_Time_New_Package)`: Minimize time for the new package.
# *   `- (Impact_on_Existing_Packages_EDT)`: Minimize delays to already committed deliveries.
# *   `- (Penalty_Express_Miss)`: High penalty if an Express delivery target is missed.
# *   `- (Penalty_Time_Window_Miss)`: Very high penalty for missing a hard time window.
#
# **`OperationalEfficiencyScore` Components:**
# *   `+ (Packages_Per_Drone_Hour_Increase)`: Reward for increasing throughput.
# *   `+ (Drone_Payload_Utilization)`: Reward for maximizing payload capacity usage on a trip.
# *   `+ (Minimize_Drone_Idle_Time)`: Reward for reducing time a drone spends unutilized.
#
# **`EnergyCostScore` Components:**
# *   `- (Estimated_Total_Energy_Consumption_Route)`: Minimize kWh for the proposed route.
# *   `- (Number_of_Battery_Swaps_or_Charges)`: Penalize if a swap/charge takes place early or unnecessarily prolongs service.
#
# **Pseudocode for `AssignPackage` Function:**
#
# ```python
# FUNCTION AssignPackage(new_package_order):
#     best_overall_score = -infinity
#     best_assignment = None  # Stores (drone_id, proposed_route, proposed_schedule)
#
#     # 1. Filter Candidate Drones
#     #   - Drones capable of carrying 'new_package_order' weight (Heavy-Duty for >2kg).
#     #   - Drones with sufficient current battery to reach pick-up/depot.
#     #   - Drones not critically assigned to unavoidable high-priority tasks.
#     candidate_drones = GetFilteredCandidateDrones(new_package_order, FSM.get_fleet_state())
#
#     FOR EACH drone IN candidate_drones:
#         # Hypothetical scenario 1: Insert 'new_package_order' into drone's current mission (if any)
#         # This is for multi-stop optimization.
#         IF drone.current_status == "in_flight" OR drone.current_status == "en_route_to_pickup":
#             proposed_route_insert, proposed_schedule_insert = RP.CalculateRoute(
#                 drone, new_package_order, assignment_type='insert_into_current_mission',
#                 fleet_state=FSM.get_fleet_state(), infra_data=IM.get_data(), env_data=EDS.get_data()
#             )
#             IF proposed_route_insert IS NOT NULL: # Check if route is feasible
#                 current_score = EvaluateObjectiveFunction(
#                     drone, proposed_route_insert, proposed_schedule_insert, new_package_order
#                 )
#                 IF current_score > best_overall_score:
#                     best_overall_score = current_score
#                     best_assignment = (drone.id, proposed_route_insert, proposed_schedule_insert)
#
#         # Hypothetical scenario 2: Assign 'new_package_order' as a new mission
#         # If drone is idle, or will be idle soon, or if inserting is worse.
#         # This can also consider picking up other pending packages if feasible.
#         proposed_route_new_mission, proposed_schedule_new_mission = RP.CalculateRoute(
#             drone, new_package_order, assignment_type='new_mission',
#             fleet_state=FSM.get_fleet_state(), infra_data=IM.get_data(), env_data=EDS.get_data()
#         )
#         IF proposed_route_new_mission IS NOT NULL: # Check if route is feasible
#             current_score = EvaluateObjectiveFunction(
#                 drone, proposed_route_new_mission, proposed_schedule_new_mission, new_package_order
#             )
#             IF current_score > best_overall_score:
#                 best_overall_score = current_score
#                 best_assignment = (drone.id, proposed_route_new_mission, proposed_schedule_new_mission)
#
#     # 2. Commit or Queue
#     IF best_overall_score > CONFIG.ASSIGNMENT_THRESHOLD: # Threshold ensures we don't pick a very bad option
#         drone_id, route, schedule = best_assignment
#         FSM.assign_package_to_drone(drone_id, new_package_order.id, route, schedule)
#         RP.update_drone_mission(drone_id, route, schedule) # Finalize detailed route
#         OMS.update_package_status(new_package_order.id, "assigned")
#         RETURN TRUE
#     ELSE:
#         OMS.add_package_to_pending_queue(new_package_order.id)
#         RETURN FALSE
#
# # Helper function for calculating scores
# FUNCTION EvaluateObjectiveFunction(drone, proposed_route, proposed_schedule, focused_package):
#     # Retrieve all packages now on this drone's mission (original + focused_package)
#     all_packages_on_mission = GetPackagesFromSchedule(proposed_schedule)
#
#     # Calculate Customer Satisfaction (W_cust_sat)
#     avg_delivery_time = CalculateAverageDeliveryTime(proposed_schedule)
#     max_delivery_time = CalculateMaximumDeliveryTime(proposed_schedule)
#     express_penalty = CalculateExpressPenalty(proposed_schedule, all_packages_on_mission)
#     time_window_penalty = CalculateTimeWindowPenalty(proposed_schedule, all_packages_on_mission)
#
#     cust_sat_score = (
#         W_CS_AVG * (-avg_delivery_time) +
#         W_CS_MAX * (-max_delivery_time) +
#         W_CS_EXP * (-express_penalty) +
#         W_CS_TW * (-time_window_penalty)
#     )
#
#     # Calculate Operational Efficiency (W_op_eff)
#     num_deliveries = len(all_packages_on_mission)
#     mission_duration = proposed_schedule.total_duration
#     drone_payload_util = CalculatePayloadUtilization(drone, all_packages_on_mission)
#
#     op_eff_score = (
#         W_OE_DEL_RATE * (num_deliveries / mission_duration) +
#         W_OE_PAYLOAD * drone_payload_util
#     )
#
#     # Calculate Energy Cost (W_energy)
#     total_energy_consumption = RP.EstimateEnergyConsumption(drone, proposed_route)
#     num_battery_stops = proposed_schedule.num_charging_or_swap_stops
#
#     energy_cost_score = (
#         W_EC_CONS * (-total_energy_consumption) +
#         W_EC_STOPS * (-num_battery_stops) # Penalize frequent stops
#     )
#
#     RETURN cust_sat_score + op_eff_score + energy_cost_score
# ```
#
# ---
#
# ### 3. Dynamic Route Planning
#
# The `RoutePlanner` is responsible for generating and updating detailed, executable flight paths. It performs continuous optimization based on real-time data.
#
# **Initial Route Calculation (VRP-like):**
# When the DS assigns a mission to a drone, the RP solves a variant of the Vehicle Routing Problem with Time Windows (VRPTW) and heterogeneous fleet constraints.
# 1.  **Stop Sequencing:** For a drone with multiple pickups/deliveries, the RP determines the optimal sequence of stops. This is a TSP-like problem solved using heuristics (e.g., insertion heuristics, savings algorithms, or metaheuristics like genetic algorithms, simulated annealing) to find the shortest/most efficient path.
# 2.  **Pathfinding:** Between each stop, an A* search algorithm (or similar shortest path algorithm) is used on the city graph, considering:
#     *   **No-Fly Zones:** Permanent and dynamic zones are strictly avoided. If a zone appears on an existing path, re-routing occurs immediately.
#     *   **Wind Conditions:** EDS provides regional wind data. The drone's ground speed and battery consumption are calculated based on its airspeed relative to the wind (e.g., `ground_speed = drone_airspeed + wind_speed_component_along_path`). Battery consumption is non-linearly affected (e.g., proportional to `(drone_airspeed - wind_component)^3` or similar aero-dynamic model).
#     *   **Payload:** Heavier payload increases battery consumption.
#     *   **Drone Model:** Light-duty (faster, less battery) vs. Heavy-duty (slower, more battery, higher payload).
# 3.  **Battery Management Integration:** The RP inherently plans for battery needs:
#     *   Estimates consumption for the entire route.
#     *   If current battery is insufficient, it identifies the optimal point in the route to divert to a depot for an instantaneous swap or a charging station for a recharge. This decision is based on comparing:
#         *   **(Time to Depot + Swap Time + Time to Next Task)** vs. **(Time to Charging Station + Recharge Time + Time to Next Task)**.
#         *   Recharge time is calculated based on current battery level, target charge level, and charging station power.
#         *   Depots are preferred due to speed, but charging stations provide more flexibility.
#     *   The chosen battery stop is inserted into the sequence of stops.
#
# **Dynamic Updates and Decision Logic:**
#
# Routes are constantly monitored and can be dynamically re-calculated or adjusted based on new events:
#
# 1.  **New Package Assignment to In-Flight Drone (Detouring):**
#     *   If the DS assigns a new high-priority package to a drone already on a mission, the RP recalculates the drone's entire remaining route.
#     *   It tries to insert the new pickup/delivery into the current sequence of stops, minimizing delays to existing packages while ensuring the new package's constraints (priority, time window) are met. This is a complex insertion heuristic.
#     *   If no feasible insertion exists, the package might be re-queued or assigned to another drone.
#
# 2.  **Drone State Changes:**
#     *   **Battery Low:** If a drone's battery drops unexpectedly (e.g., due to stronger headwind than forecasted), the RP immediately re-evaluates the drone's ability to reach its next destination *and* a charging facility. It might trigger an immediate diversion to the nearest safe landing spot, depot, or charging station, overriding existing tasks.
#     *   **Package Delivered/Picked Up:** Upon confirmation, the drone's task list is updated, potentially triggering the next leg of its mission.
#
# 3.  **Environmental Changes:**
#     *   **Dynamic No-Fly Zone:** If a new no-fly zone appears along a drone's current or planned path, the RP immediately recalculates an alternative path avoiding the zone. If no viable path exists (e.g., drone is trapped or cannot avoid), it initiates an emergency landing procedure to the nearest safe location.
#     *   **Weather Deterioration:** If wind speeds increase significantly or other adverse conditions emerge, the RP recalculates estimated flight times and battery consumption. This might trigger early battery management actions or even a temporary grounding if conditions become unsafe, leading to re-assignment of packages.
#
# 4.  **Emergency Situations (Robustness):**
#     *   **Drone Malfunction:** Upon receiving a malfunction alert from FSM, the RP's priority is to guide the drone to the nearest safe landing zone or depot, bypassing all other tasks. All packages on board are immediately marked for re-assignment by the DS.
#
# ---
#
# ### 4. Scalability and Robustness
#
# **Scalability:**
#
# *   **Computational Complexity:**
#     *   **Assignment Heuristic:** The core bottleneck is the `RP.CalculateRoute` function, which is a VRP-like problem. For `N_drones` and `K` packages (stops), an exact solution is NP-hard. Our approach uses heuristics. If `CalculateRoute` takes `O(K^2)` or `O(K^3)` with good heuristics (e.g., greedy insertion, local search), then the `AssignPackage` function would be `O(N_drones * K^x)`.
#     *   **Route Planning:** The A* pathfinding between stops is typically `O(E + V log V)` where E is edges, V is vertices in the city graph.
# *   **Strategies for Scaling:**
#     1.  **Hierarchical Zoning:** The city is divided into operational zones. Drones are primarily assigned to zones. New orders first seek drones within their zone, then adjacent, then globally. This limits the `N_drones` and `K` considered in `CalculateRoute` for most common scenarios.
#     2.  **Pre-computation & Caching:**
#         *   Pre-calculate shortest paths and battery costs between critical nodes (depots, major hubs, common vendor/customer clusters) for different drone types and average weather.
#         *   Cache results of `RP.CalculateRoute` for similar drone states and package combinations.
#     3.  **Approximate Algorithms & Heuristics:** Rely heavily on efficient approximation algorithms for the VRP-like problems within the RP. Machine learning models can be trained offline to quickly predict good routes or assignments.
#     4.  **Parallel Processing:** The evaluation of `candidate_drones` in the `AssignPackage` function can be parallelized. Each drone's potential route can be assessed concurrently.
#     5.  **Rolling Horizon Optimization:** Instead of optimizing for the entire day, the DS might re-optimize the schedule for the next 1-2 hours or for the next `X` packages, then re-evaluate. This reduces the problem size.
#     6.  **Event-Driven Architecture:** Calculations are only triggered by significant events (new order, drone status change, environmental update), not on a fixed, frequent cycle for the entire fleet.
#     7.  **Priority-Based Resource Allocation:** Critical packages (Express, time-window) or drones in critical states (low battery, malfunction) receive higher computational priority for route planning.
#
# **Robustness:**
#
# The system is designed to handle unexpected events gracefully:
#
# 1.  **Drone Malfunctions:**
#     *   **Detection:** FSM immediately detects anomaly through telemetry (e.g., unusual attitude, power drop).
#     *   **Action:** RP receives notification and immediately calculates a new, shortest, safest path to the nearest safe landing zone or depot. All packages on board are removed from the drone's manifest and put back into the OMS's `PendingOrdersQueue` with elevated priority.
#     *   **Re-assignment:** DS is triggered to re-assign these critical packages to other available drones.
#
# 2.  **Sudden Weather Deterioration:**
#     *   **Detection:** EDS provides real-time updates. If conditions (e.g., extreme wind, heavy rain) exceed drone operational limits or significantly impact battery life.
#     *   **Action:** RP re-calculates all affected drone routes. Drones might be re-routed to avoid severe zones, land early at safe spots, or divert to a depot. In extreme cases, a general "grounding" order might be issued, and all in-flight packages are marked for re-assignment when conditions improve.
#
# 3.  **Dynamic No-Fly Zone Appearance:**
#     *   **Detection:** IM receives immediate updates from external authorities.
#     *   **Action:** RP is immediately triggered for all drones whose paths intersect the new zone. New routes are calculated avoiding the zone. If a drone is already inside, it calculates the fastest, safest exit path. Packages may experience delays, and critical packages might trigger re-assignment if delays are too long.
#
# 4.  **Package Cancellation/Priority Change:**
#     *   **Action:** OMS updates the package status. If cancelled, the drone's route is immediately re-optimized to remove the stop. If priority changes, the package might be re-evaluated for assignment or for insertion into another drone's route.
#
# 5.  **Depot/Charging Station Unavailability:**
#     *   **Detection:** IM monitors status.
#     *   **Action:** RP will only consider available facilities. If a drone was en route to a now-unavailable facility, it will be re-routed to the next best option.
#
# 6.  **Redundancy and Failover:** Maintain a pool of pre-charged, idle drones at various depots to quickly replace malfunctioning drones or handle surge demand. The central control system can be architected with failover mechanisms to ensure continuous operation.
#
# ---
#
# ### 5. Evaluation Strategy
#
# A robust simulation framework is essential to validate the algorithm's performance, especially given the multi-objective optimization and dynamic environment.
#
# **Simulation Framework:**
#
# 1.  **City Model:**
#     *   **Geographical Graph:** Represent the city as a weighted directed graph where nodes are intersections, potential pick-up/drop-off points, depots, and charging stations. Edges represent flight paths with associated distances, base travel times, and altitude profiles.
#     *   **No-Fly Zones:** Define static and dynamic no-fly zone polygons.
#     *   **Depots & Charging Stations:** Locations, capacities (for charging stations), battery swap times (instantaneous for depots).
# 2.  **Drone Models:**
#     *   **Parameters:** For Light-Duty and Heavy-Duty drones: Max payload, battery capacity, base cruise speed, battery consumption rate (idle, flying, varying with payload and airspeed relative to wind), charging rate.
#     *   **Failure Model:** Introduce a probability of random drone malfunctions (e.g., engine failure, navigation error) at varying rates.
# 3.  **Package Generator:**
#     *   **Arrival Rate:** Configurable arrival rate for new orders (e.g., Poisson process, or historical data-driven). Can simulate peak hours vs. off-peak.
#     *   **Package Attributes:** Randomly generate:
#         *   Vendor/Customer Locations (spatial distribution mimicking urban density).
#         *   Weight (within drone limits).
#         *   Priority (Standard/Express ratio).
#         *   Time Window Constraints (percentage of orders).
#         *   Delivery Deadlines (for Express, general target).
# 4.  **Environmental Model:**
#     *   **Weather Service:** Simulate a forecasting service providing regional wind speed/direction, precipitation, temperature, updated periodically. Wind model should vary spatially and temporally.
#     *   **Dynamic No-Fly Zones:** Events for sudden appearance/disappearance of temporary no-fly zones.
# 5.  **Event-Driven Simulator:**
#     *   Advance time in discrete steps or based on events.
#     *   Process events: package arrival, drone departure/arrival at waypoint/stop, battery level update, weather update, drone malfunction, no-fly zone change.
#     *   Record all drone movements, battery consumption, package statuses, and decisions made by the DS/RP.
#
# **Metrics to Track (aligned with KPIs):**
#
# 1.  **Customer Satisfaction:**
#     *   **Average Delivery Time (ADT):** Mean time from order placement to delivery completion.
#     *   **Maximum Delivery Time (MDT):** Longest delivery time observed.
#     *   **Express On-Time Rate:** Percentage of Express packages delivered within their target time.
#     *   **Time Window Compliance:** Percentage of packages delivered within their specified time windows.
#     *   **Penalty Score:** Sum of all incurred penalties for missed targets/windows.
#
# 2.  **Operational Efficiency:**
#     *   **Throughput:** Total packages delivered per simulation hour/day.
#     *   **Deliveries per Drone Hour:** Average number of deliveries made by an individual drone per hour of its operational time.
#     *   **Drone Utilization Rate:** Percentage of time drones are actively flying with a payload (excluding idle time, charging, maintenance).
#     *   **Payload Utilization:** Average percentage of maximum payload capacity utilized per flight segment.
#     *   **Multi-Package Delivery Rate:** Percentage of deliveries that are part of a multi-stop route.
#     *   **Idle Time:** Average time drones spend waiting for tasks.
#
# 3.  **Energy Cost:**
#     *   **Total Energy Consumption (kWh):** Sum of all battery energy consumed across the fleet.
#     *   **Energy per Delivery (kWh/delivery):** Total energy divided by total deliveries.
#     *   **Battery Cycle Count:** Number of full charge/discharge cycles experienced by batteries (related to battery lifespan).
#     *   **Charging/Swap Time:** Total time spent by fleet either charging or undergoing battery swaps.
#
# **Baseline Strategies for Comparison:**
#
# 1.  **Nearest Available Drone (NAD):** A simple greedy approach where a new package is assigned to the closest drone that can physically carry it and has enough battery to complete the mission. No multi-stop optimization.
# 2.  **First Available Drone (FAD):** Assign to the first drone that becomes idle and can take the package, regardless of proximity.
# 3.  **Homogeneous Fleet (e.g., All Light-Duty or All Heavy-Duty):** Run simulations using only one type of drone to quantify the benefits of fleet heterogeneity.
# 4.  **Greedy Multi-Stop (without advanced battery/weather):** A NAD approach that attempts to combine deliveries into multi-stop routes but lacks sophisticated battery planning or real-time weather integration.
#
# **Experimentation & Analysis:**
#
# *   **Varying Load:** Run simulations under low, medium, and high package arrival rates to test scalability.
# *   **Parameter Sensitivity:** Vary the weights (W_cust_sat, W_op_eff, W_energy) in the objective function to understand trade-offs and find optimal balance.
# *   **Environmental Stress Tests:** Simulate frequent and severe weather changes, high rates of dynamic no-fly zones, and drone malfunctions to assess robustness.
# *   **Fleet Composition:** Experiment with different ratios of Light-Duty vs. Heavy-Duty drones.
# *   **Statistical Significance:** Run multiple simulation trials for each scenario with different random seeds to ensure statistical significance of results.
#
# By systematically comparing the proposed algorithm against these baselines and across various operational conditions, its effectiveness, scalability, and robustness can be thoroughly evaluated.
# Professor model received solution: The deployment of a heterogeneous autonomous drone fleet for real-time delivery in a dynamic urban environment presents a complex optimization challenge. The goal is to balance customer satisfaction, operational efficiency, and energy cost, which often conflict. This design outlines a robust, scalable algorithm to address these challenges.
#
# ---
#
# ## Real-Time Heterogeneous Drone Scheduling and Routing System
#
# ### 1. System Architecture
#
# The system operates under a central control platform, integrating various modules for real-time data processing, decision-making, and drone command.
#
# **High-Level Components:**
#
# 1.  **Order Management System (OMS):**
#     *   **Function:** Receives new package orders from various vendors, validates them, and assigns unique IDs. Manages package priorities (Standard, Express), weights, delivery time windows, and current status.
#     *   **Input:** Real-time package requests.
#     *   **Output:** Prioritized package queue to the Dynamic Scheduler.
#
# 2.  **Fleet State Monitor (FSM):**
#     *   **Function:** Maintains a comprehensive, real-time database of all drones in the fleet. Tracks drone location (GPS), current status (idle, flying, charging, maintenance, malfunctioning), battery level, current payload, assigned tasks, and estimated time of arrival (ETA) at next waypoint/destination.
#     *   **Input:** Telemetry data from drones.
#     *   **Output:** Real-time drone status to Dynamic Scheduler and Route Planner.
#
# 3.  **Infrastructure Manager (IM):**
#     *   **Function:** Manages static and dynamic infrastructure data. Tracks locations and availability of depots (with battery swap capabilities) and public charging stations. Monitors capacity and queue times for charging stations. Manages permanent and dynamic no-fly zones.
#     *   **Input:** Static infrastructure data, real-time status from depots/charging stations, updates on dynamic no-fly zones (e.g., from air traffic control).
#     *   **Output:** Infrastructure availability and no-fly zone data to Dynamic Scheduler and Route Planner.
#
# 4.  **Environmental Data Service (EDS):**
#     *   **Function:** Integrates real-time and forecasted environmental data, primarily weather conditions (wind speed, direction, precipitation, temperature) across different city regions.
#     *   **Input:** APIs from weather forecasting services.
#     *   **Output:** Regional weather data to Route Planner for flight path calculation and battery consumption estimation.
#
# 5.  **Dynamic Scheduler (DS) - *The Brain*:**
#     *   **Function:** The core decision-making unit. Upon receiving a new order or a drone becoming available, it determines the optimal drone (or set of drones) to assign tasks to. It uses a sophisticated heuristic to evaluate potential assignments against the multi-objective KPIs.
#     *   **Input:** Package queue from OMS, drone states from FSM, infrastructure data from IM, environmental data from EDS.
#     *   **Output:** Drone assignments and high-level mission plans to the Route Planner.
#
# 6.  **Route Planner (RP):**
#     *   **Function:** Detailed pathfinding for individual drones. Given a drone and a sequence of tasks (pickups/deliveries/charging), it calculates the precise flight path (sequence of waypoints), considering no-fly zones, wind conditions, battery consumption, and drone specific parameters. It also estimates ETA for each leg and overall mission duration.
#     *   **Input:** Drone assignment and mission plan from DS, detailed drone specs, infrastructure data from IM, environmental data from EDS.
#     *   **Output:** Optimized flight plan (waypoints, speeds, estimated battery use, ETAs) to the Communication Module.
#
# 7.  **Communication Module:**
#     *   **Function:** Facilitates secure, real-time communication between the central system and individual drones. Sends flight plans and receives telemetry data.
#     *   **Input:** Flight plans from RP.
#     *   **Output:** Drone commands, receives drone telemetry.
#
# 8.  **Database/Knowledge Base:**
#     *   **Function:** Stores all static and dynamic data (drone specifications, depot locations, historical package data, past route performance, etc.) to support all modules.
#
# **Interaction Flow:**
#
# 1.  **New Order:** OMS receives an order and adds it to the package queue.
# 2.  **Assignment Request:** DS continuously monitors the package queue and available/soon-to-be-available drones.
# ...
#     *   **Average Drone Utilization:** Percentage of time drones are actively flying/delivering. (Expected: Robust might be slightly lower due to buffer times.)
#     *   **Total Energy Consumption:** (Expected: Robust might be slightly higher due to potentially longer/safer routes.)
#     *   **Average Queue Times at Depots/Charging Stations:** (Expected: Robust might plan for slightly higher buffers, but potentially fewer *unexpected* long waits.)
#
# **Hypothesis:**
# Under conditions of **moderate to high uncertainty**, the **robust optimization approach (Treatment B)** is expected to yield:
# *   **Higher Net Profitability**, primarily due to significantly **fewer penalties from missed/late deliveries**, even if it incurs slightly higher operational costs or results in slightly lower average drone utilization.
# *   **Significantly improved reliability** (fewer missed deadlines, lower variance in delivery times), leading to greater customer satisfaction.
#
# This experiment will quantitatively demonstrate the value proposition of investing in robust optimization over simpler expected-value approaches when operating in dynamic, uncertain environments.
# for prompt: A city is deploying a heterogeneous fleet of autonomous delivery drones. This system operates in a dynamic environment where new package orders from various vendors arrive in real-time. Your task is to design a state-of-the-art, adaptive algorithm for real-time drone scheduling and routing that incorporates optimization, machine learning, and considers long-term operational and societal factors.
#
# **System Components & Constraints:**
#
# 1.  **Heterogeneous Drone Fleet:**
#     *   **Light-Duty:** 30km battery range (no load, no wind), max payload 2kg, 60 km/h cruise airspeed.
#     *   **Heavy-Duty:** 50km battery range (no load, no wind), max payload 10kg, 45 km/h cruise airspeed.
#     *   All drones can carry multiple packages, batched into consolidated trips.
#
# 2.  **Infrastructure & Battery Management:**
#     *   **Depots:** Multiple depots with a limited number of **automated swap bays**. A battery swap takes a fixed **3 minutes**, but drones may have to **queue**.
#     *   **Charging Stations:** A denser network of public charging pads. Charging time is non-linear. Electricity costs **vary by time of day**. Stations have limited pads, leading to potential queuing.
#     *   **Battery Health Model:** Each charge/discharge cycle, especially fast charging, slightly degrades the battery's maximum capacity. This degradation must be modeled as a long-term operational cost, influencing the choice between slow charging, fast charging, and swapping.
#
# 3.  **Packages & Economics:**
#     *   Orders have varying weights and two priority levels: **Standard** and **Express**.
#     *   **Financial Penalties:** Missing an Express delivery target incurs a monetary penalty that increases with the delay. Missing a hard time-window constraint results in a larger, fixed penalty.
#
# 4.  **Operating Environment:**
#     *   The city has permanent and **dynamic no-fly zones**.
#     *   **Weather Model:** A forecasting service provides a grid-based wind map. The drone's power consumption is proportional to the cube of its airspeed relative to the wind: `Power ∝ (airspeed_relative_to_wind)³`.
#
# 5.  **Societal & Regulatory Constraints:**
#     *   **Noise Pollution Model:** Drone noise is a public concern. Flights over residential areas during specific hours (e.g., 10 PM - 7 AM) incur a non-monetary "noise penalty" that the optimizer must consider.
#     *   **Fairness Metric:** The system must not persistently neglect or provide poor service to certain geographical zones, even if they are less profitable. A fairness constraint (e.g., maintaining a minimum service level or maximum wait time across all zones) must be incorporated.
#
# **Task & Objectives:**
#
# Design a dynamic scheduling and routing system. Your primary goal is to maximize the system's **long-term Net Profitability**, which requires optimizing a complex objective that balances:
#
# 1.  **Customer Satisfaction:** Minimize financial penalties from late/missed deliveries.
# 2.  **Operational Throughput:** Maximize the number of deliveries completed.
# 3.  **Immediate Operational Cost:** Minimize energy and swap costs.
# 4.  **Long-Term Asset Health:** Minimize battery degradation to reduce replacement costs.
# 5.  **Societal Acceptance:** Adhere to noise and fairness constraints.
#
# **Your response must detail the following:**
#
# 1.  **System Architecture & Human Oversight:**
#     *   Describe the high-level software components and their interactions. Justify your chosen scheduling paradigm (e.g., event-driven vs. rolling-horizon).
#     *   Detail the **Human-in-the-Loop (HITL)** interface. How does the system visualize complex trade-offs (e.g., sacrificing one express delivery to save three others from being late) to a human operator for strategic oversight or intervention in ambiguous, high-stakes scenarios?
#
# 2.  **Core Optimization Model & Uncertainty Handling:**
#     *   Instead of high-level pseudocode, provide a partial **mathematical formulation** (e.g., Mixed-Integer Linear Programming) for a core component of your model, such as assigning a batch of packages to a single drone's multi-stop tour. Clearly define the decision variables, objective function, and key constraints for this sub-problem.
#     *   Crucially, discuss how your model will handle the **uncertainty** inherent in ML predictions (e.g., travel times, queue waits). Compare two approaches: a) using expected values versus b) using a **robust or stochastic optimization** method that explicitly considers prediction variance to create more reliable schedules.
#
# 3.  **Dynamic Re-routing and Decision Logic:**
#     *   When a new high-priority Express order arrives, provide a specific, quantitative **cost-benefit function** for diverting an in-flight drone.
#     *   Explain how this function adapts if the ML-predicted travel times for the proposed new route have **high variance or uncertainty**. Does the decision logic become more conservative?
#
# 4.  **Machine Learning Integration & MLOps:**
#     *   Propose at least **two distinct ML models**. For one, instead of a standard predictive model, propose a **Reinforcement Learning (RL) agent that learns a meta-heuristic policy**, such as deciding which "destroy" and "repair" operators to apply in a Large Neighborhood Search algorithm to solve the routing problem more effectively over time.
#     *   Detail the **MLOps strategy** for your models. How will you detect and mitigate concept/data drift (e.g., as seasonal demand patterns change)? Describe the automated retraining, validation, and deployment pipeline for your most critical predictive model.
#
# 5.  **Scalability and Decentralization:**
#     *   Detail strategies to ensure the system scales (e.g., hierarchical zoning, parallelization).
#     *   Discuss the potential benefits and complexities of adding a **decentralized component**, such as direct drone-to-drone (D2D) communication for local deconfliction or collaborative task execution (e.g., in-air package handoffs), and how this would interface with your centralized scheduler.
#     *   Describe the system's failover logic for a cascade of failures, such as a major weather event grounding all drones in one sector of the city.
#
# 6.  **Evaluation Strategy:**
#     *   Propose a simulation framework to test your algorithm.
#     *   In addition to Net Profitability, detail how your simulation will **quantitatively measure the new societal objectives**. Define specific metrics for a) noise impact (e.g., number of residents overflown during quiet hours) and b) service fairness across different city zones (e.g., Gini coefficient of delivery times).
#     *   Design an experiment to isolate and measure the value added by your **robust/stochastic optimization approach** compared to a baseline that uses only the mean/expected values from ML predictions.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3280548734.py in <cell line: 0>()
#      33
#      34     # Professor evaluates the solution and returns a refined prompt
# ---> 35     next_refined_prompt = professor_model(student_solution, current_prompt)
#      36     prompt_history.append(next_refined_prompt)
#      37     print(f"\nProfessor's Feedback (Returned Refined Prompt - Iteration {iteration_number}):\n{next_refined_prompt}")
#
# /tmp/ipython-input-1603905391.py in professor_model(student_solution, current_prompt)
#      27     # Generate the refined prompt using the professor model
#      28     try:
# ---> 29         response = professor_llm.generate_content(professor_prompt_text)
#      30         if response.text:
#      31             next_refined_prompt = response.text.strip()
#
# /usr/local/lib/python3.12/dist-packages/google/generativeai/generative_models.py in generate_content(self, contents, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     329                 return generation_types.GenerateContentResponse.from_iterator(iterator)
#     330             else:
# --> 331                 response = self._client.generate_content(
#     332                     request,
#     333                     **request_options,
#
# /usr/local/lib/python3.12/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py in generate_content(self, request, model, contents, retry, timeout, metadata)
#     833
#     834         # Send the request.
# --> 835         response = rpc(
#     836             request,
#     837             retry=retry,
#
# /usr/local/lib/python3.12/dist-packages/google/api_core/gapic_v1/method.py in __call__(self, timeout, retry, compression, *args, **kwargs)
#     129             kwargs["compression"] = compression
#     130
# --> 131         return wrapped_func(*args, **kwargs)
#     132
#     133
#
# /usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py in retry_wrapped_func(*args, **kwargs)
#     292                 self._initial, self._maximum, multiplier=self._multiplier
#     293             )
# --> 294             return retry_target(
#     295                 target,
#     296                 self._predicate,
#
# /usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     145     while True:
#     146         try:
# --> 147             result = target()
#     148             if inspect.isawaitable(result):
#     149                 warnings.warn(_ASYNC_RETRY_WARNING)
#
# /usr/local/lib/python3.12/dist-packages/google/api_core/timeout.py in func_with_timeout(*args, **kwargs)
#     128                 kwargs["timeout"] = remaining_timeout
#     129
# --> 130             return func(*args, **kwargs)
#     131
#     132         return func_with_timeout
#
# /usr/local/lib/python3.12/dist-packages/google/api_core/grpc_helpers.py in error_remapped_callable(*args, **kwargs)
#      73     def error_remapped_callable(*args, **kwargs):
#      74         try:
# ---> 75             return callable_(*args, **kwargs)
#      76         except grpc.RpcError as exc:
#      77             raise exceptions.from_grpc_error(exc) from exc
#
# /usr/local/lib/python3.12/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/transports/rest.py in __call__(self, request, retry, timeout, metadata)
#    1146
#    1147             # Send the request
# -> 1148             response = GenerativeServiceRestTransport._GenerateContent._get_response(
#    1149                 self._host,
#    1150                 metadata,
#
# /usr/local/lib/python3.12/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/transports/rest.py in _get_response(host, metadata, query_params, session, timeout, transcoded_request, body)
#    1046             headers = dict(metadata)
#    1047             headers["Content-Type"] = "application/json"
# -> 1048             response = getattr(session, method)(
#    1049                 "{host}{uri}".format(host=host, uri=uri),
#    1050                 timeout=timeout,
#
# /usr/local/lib/python3.12/dist-packages/requests/sessions.py in post(self, url, data, json, **kwargs)
#     635         """
#     636
# --> 637         return self.request("POST", url, data=data, json=json, **kwargs)
#     638
#     639     def put(self, url, data=None, **kwargs):
#
# /usr/local/lib/python3.12/dist-packages/google/auth/transport/requests.py in request(self, method, url, data, headers, max_allowed_time, timeout, **kwargs)
#     533         with TimeoutGuard(remaining_time) as guard:
#     534             _helpers.request_log(_LOGGER, method, url, data, headers)
# --> 535             response = super(AuthorizedSession, self).request(
#     536                 method,
#     537                 url,
#
# /usr/local/lib/python3.12/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     587         }
#     588         send_kwargs.update(settings)
# --> 589         resp = self.send(prep, **send_kwargs)
#     590
#     591         return resp
#
# /usr/local/lib/python3.12/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     701
#     702         # Send the request
# --> 703         r = adapter.send(request, **kwargs)
#     704
#     705         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.12/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     665
#     666         try:
# --> 667             resp = conn.urlopen(
#     668                 method=request.method,
#     669                 url=url,
#
# /usr/local/lib/python3.12/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     785
#     786             # Make the request on the HTTPConnection object
# --> 787             response = self._make_request(
#     788                 conn,
#     789                 method,
#
# /usr/local/lib/python3.12/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532         # Receive the response from the server
#     533         try:
# --> 534             response = conn.getresponse()
#     535         except (BaseSSLError, OSError) as e:
#     536             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /usr/local/lib/python3.12/dist-packages/urllib3/connection.py in getresponse(self)
#     563
#     564         # Get the response from http.client.HTTPConnection
# --> 565         httplib_response = super().getresponse()
#     566
#     567         try:
#
# /usr/lib/python3.12/http/client.py in getresponse(self)
#    1428         try:
#    1429             try:
# -> 1430                 response.begin()
#    1431             except ConnectionError:
#    1432                 self.close()
#
# /usr/lib/python3.12/http/client.py in begin(self)
#     329         # read until we get a non-100 response
#     330         while True:
# --> 331             version, status, reason = self._read_status()
#     332             if status != CONTINUE:
#     333                 break
#
# /usr/lib/python3.12/http/client.py in _read_status(self)
#     290
#     291     def _read_status(self):
# --> 292         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293         if len(line) > _MAXLINE:
#     294             raise LineTooLong("status line")
#
# /usr/lib/python3.12/socket.py in readinto(self, b)
#     718         while True:
#     719             try:
# --> 720                 return self._sock.recv_into(b)
#     721             except timeout:
#     722                 self._timeout_occurred = True
#
# KeyboardInterrupt:
